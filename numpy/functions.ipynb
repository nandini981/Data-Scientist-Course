# %%
import numpy as np

# %%
arr = np.array([3,4,5,6,33])

# %%
np.mean(arr)
# Out:
# np.float64(10.2)

# %%
np.min(arr)
# Out:
# np.int64(3)

# %%
np.max(arr)
# Out:
# np.int64(33)

# %%
np.std(arr)
# Out:
# np.float64(11.443775600735973)

# %%
np.var(arr)
# Out:
# np.float64(130.95999999999998)

# %%
np.sum(arr)
# Out:
# np.int64(51)

# %%
np.prod(arr)
# Out:
# np.int64(11880)

# %%
np.median(arr)
# Out:
# np.float64(5.0)

# %%
np.percentile(arr,100)
# Out:
# np.float64(33.0)

# %%
np.subtract(arr,10)
# Out:
# array([-7, -6, -5, -4, 23])

# %%
np.argmin(arr) #returns index
# Out:
# np.int64(0)

# %%
arr
# Out:
# array([ 3,  4,  5,  6, 33])

# %%
np.argmax(arr)
# Out:
# np.int64(4)

# %%
arr3 = np.array([1,2,2,2,44,44,44,3])
arr3
# Out:
# array([ 1,  2,  2,  2, 44, 44, 44,  3])

# %%
np.unique(arr3)
# Out:
# array([ 1,  2,  3, 44])

# %%
np.cumsum(arr3)
# Out:
# array([  1,   3,   5,   7,  51,  95, 139, 142])

# %%
np.linspace(arr3,2)
# Out:
# array([[ 1.        ,  2.        ,  2.        ,  2.        , 44.        ,
#         44.        , 44.        ,  3.        ],
#        [ 1.02040816,  2.        ,  2.        ,  2.        , 43.14285714,
#         43.14285714, 43.14285714,  2.97959184],
#        [ 1.04081633,  2.        ,  2.        ,  2.        , 42.28571429,
#         42.28571429, 42.28571429,  2.95918367],
#        [ 1.06122449,  2.        ,  2.        ,  2.        , 41.42857143,
#         41.42857143, 41.42857143,  2.93877551],
#        [ 1.08163265,  2.        ,  2.        ,  2.        , 40.57142857,
#         40.57142857, 40.57142857,  2.91836735],
#        [ 1.10204082,  2.        ,  2.        ,  2.        , 39.71428571,
#         39.71428571, 39.71428571,  2.89795918],
#        [ 1.12244898,  2.        ,  2.        ,  2.        , 38.85714286,
#         38.85714286, 38.85714286,  2.87755102],
#        [ 1.14285714,  2.        ,  2.        ,  2.        , 38.        ,
#         38.        , 38.        ,  2.85714286],
# ...

# %%
np.log(arr)
# Out:
# array([1.09861229, 1.38629436, 1.60943791, 1.79175947, 3.49650756])

# %%
np.exp(arr3)
# Out:
# array([2.71828183e+00, 7.38905610e+00, 7.38905610e+00, 7.38905610e+00,
#        1.28516001e+19, 1.28516001e+19, 1.28516001e+19, 2.00855369e+01])
