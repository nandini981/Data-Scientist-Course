# %%
import numpy as np

# %%
arr = np.array([23,34,4,5,23])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([23., 34.,  4.,  5., 23.])

# %%
arr2 = np.array([12,3,4,34,5],dtype=np.int64)

# %%
arr2
# Out:
# array([12,  3,  4, 34,  5])

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
arr2.nbytes
# Out:
# 40

# %%
arr2 = np.array([12,3,4,34,5],dtype=np.int32)

# %%
arr2.nbytes
# Out:
# 20
